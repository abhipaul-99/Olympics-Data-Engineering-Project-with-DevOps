# %%
from pyspark.sql.functions import * 
from pyspark.sql.types import *

# %%
dbutils.widgets.text("source_container", "")
dbutils.widgets.text("sink_container", "")
dbutils.widgets.text("folder", "")

# %%
source_container = dbutils.widgets.get("source_container")
sink_container = dbutils.widgets.get("sink_container")
folder = dbutils.widgets.get("folder")

print(source_container)
print(sink_container)
print(folder)
# Out:
# bronze
# silver
# coaches

# %%
df = spark.read.format('parquet')\
                .load(f"abfss://{source_container}@parisolympicstorage.dfs.core.windows.net/{folder}")

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .option("path", f"abfss://{sink_container}@parisolympicstorage.dfs.core.windows.net/{folder}")\
    .saveAsTable(f"olympics.{sink_container}.{folder}")
