# %%
file_list = [
    {
        'source_container': 'bronze',
        'sink_container' : 'silver',
        'folder': 'coaches'
    },
    {
        'source_container': 'bronze',
        'sink_container' : 'silver',
        'folder': 'events'
    }
]

# %%
dbutils.jobs.taskValues.set("file_list", file_list)
